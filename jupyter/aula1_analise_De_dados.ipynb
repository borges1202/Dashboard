# %%
import pandas as pd

# %%
df_nfe = pd.read_csv("2025_nfe.csv",encoding="Windows-1252", sep=";")

# %%
soma = df_nfe ["VALOR NOTA FISCAL"].str.replace(",",".").astype(float).sum()

# %%
# Out:
#                                      CHAVE DE ACESSO  \
# 0       32250148658655000188550010000007301109131230
# 1       51250104695497000160550110000434184166743940
# 2       51250104695497000160550110000434191056340194
# 3       33250128503456000193550020000440181101927108
# 4       33250129051570000192550060000573941110143139
# ...                                              ...
# 113071  29250113937073000156558900045132251511557636
# 113072  35250134274233038509550000002406311812766090
# 113073  24250141412829000189550010000010021418752843
# 113074  51250126588921000100550020000751791312358339
# 113075  43250188587357006019550020000562931000181730
#
#                                                    MODELO  SÉRIE   NÚMERO  \
# 0       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...      1      730
# 1       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...     11    43418
# 2       55 - NF-E EMITIDA EM SUBSTITUIÇÃO AO MODELO 1 ...     11    43419
# ...
